# %%
import torch
from torch.autograd import Variable
from transformers import (
    AutoTokenizer,
    Adafactor,
    DataCollatorForSeq2Seq,
    AutoModelForSeq2SeqLM,
    Seq2SeqTrainingArguments,
    Seq2SeqTrainer,
)
from datasets import load_dataset, load_metric

import wandb

wandb.login()
# %env WANDB_PROJECT=WebNLG_exp_bs

# %load_ext jupyter_black

# Use gpu
if torch.cuda.is_available():
    dev = torch.device("cuda:0")
    print("Running on the GPU")
else:
    dev = torch.device("cpu")
    print("Running on the CPU")

tokenizer = AutoTokenizer.from_pretrained("t5-base")
model = AutoModelForSeq2SeqLM.from_pretrained("t5-base").to(dev)
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)
# Out:
# env: WANDB_PROJECT=WebNLG_exp_bs
# The jupyter_black extension is already loaded. To reload it, use:
#   %reload_ext jupyter_black
# Running on the GPU

# %%
dataset = load_dataset(
    "csv",
    data_files={
        "train": "../datasets/train_set.csv",
        "dev": "../datasets/dev_set.csv",
        "test": "../datasets/test_set.csv",
    },
)


def data_map(examples):
    inputs = ["WebNLG: " + eg + "</s>" for eg in examples["triple"]]
    outputs = [eg + "</s>" for eg in examples["sentence"]]
    model_inputs = tokenizer(
        inputs, max_length=tokenizer.model_max_length, truncation=True
    )

    with tokenizer.as_target_tokenizer():
        labels = tokenizer(
            outputs, max_length=tokenizer.model_max_length, truncation=True
        )

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs


dataset = dataset.map(
    data_map,
    batched=True,
    batch_size=8,
    num_proc=32,
)
# Out:
# WARNING:datasets.builder:Using custom data configuration default-3c0b0f77305be40c
# WARNING:datasets.builder:Reusing dataset csv (/home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-1e3be36790c3d99b.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-01384c5efb94b22d.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-9979e2c2f35b0069.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-77d897e520d4b4ff.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-839ae967dbbbcc1f.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-90e17ce630f4c756.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-735ed276d3045e27.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-9a16a8b7fbc24b47.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-785b505dd324ca73.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-6a115f1327d7acfa.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-5ffb137f273a2991.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-39c83f5e8c7c780c.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-9e78952ef7fe1572.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-191c5a2108a1a885.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-7649dab03ae318e3.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-04a57be24251af29.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-63b51881c7f3cfab.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-4d743cfc04af27c9.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-51345587208b271f.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-d7414b8c9c34a004.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-a2fbb571c6e1087c.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-7cefbf377c2263fc.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-0da981343840e767.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-ae9d06666106deac.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-d6a83b3eb9358509.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-9e10112c8eaa01f2.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-ddcdd9c4baf77d96.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-0c38713a85515850.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-ac14ba1db34dd284.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-c20dbb0fdd096602.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-f01799c4d4213a09.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-dd85544a9a8c4393.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-2cf9c03198f2bc75.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-f9897b443a024fce.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-460aee91cc76c982.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-578eee1fc7cfd647.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-560ff107b69359a3.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-82d01eb29dae01d8.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-ed9666080efa10f4.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-2b8450be7d51a6a2.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-4c16d6c576b73469.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-1407835c643ecf9b.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-8846934e7ee1b5c8.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-018db219104d2ed7.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-1ae04a4459339ca2.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-847d697060160275.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-81ca640425b47ee7.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-c58cdc603b025c8f.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-58d1723b22ad8e2f.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-91008b588b7db901.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-7671f1d99c7b3bcc.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-c65d6868678f0a67.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-364c23bc5ee88eed.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-24cb809d746ba332.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-f65140e82b12c21e.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-a9c8edb5d87afa62.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-c25e02b5cfe17c68.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-f3d172faecc5954f.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-4e0ccb85b97d2f98.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-fd3ec219f3d7c697.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-0be97aa6aa5f51db.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-9a1573e8af12ba83.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-fed92d88d20b76ec.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-7a15d28a947e3dd8.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-d65c148a7364c76a.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-bd1b95d290589334.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-f79d885484e17ef9.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-7455b469594afbfb.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-989482dd50f86335.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-0dc29c0e0b05af2b.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-ecb92a50a279293e.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-bfa176d412362680.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-4a98921cad396a53.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-507a554d9173d9f7.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-0ff6e0069524fb4f.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-d364839aa95b73a2.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-cc4d443a5a1be991.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-a0f76569bf9bfdae.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-a6ccb705d93089a3.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-bea0a3776f54b00f.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-7794f9d60f4803d6.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-7ba3fa1b3d651030.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-50b007abad7e9c75.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-9ab92624f4e8d393.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-67f9d6ab89643d13.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-166013360b069d13.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-c70791ff0811271d.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-ad3cbf7e69b6f18c.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-0d8fd0cc73a28907.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-dd6dea54c1cb1886.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-4c1dbaa117aefb67.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-0c76709fb6aa5e21.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-796bdb2f26eeb0a9.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-1ba45b8c1f292e98.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-c5d97e5cbdfcca43.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /home/ml/.cache/huggingface/datasets/csv/default-3c0b0f77305be40c/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519/cache-f9600ee26ae513b2.arrow

# %%
bleu = load_metric("bleu")
ter = load_metric("ter")


def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    b = bleu.compute(predictions=predictions, references=labels)
    t = ter.compute(predictions=predictions, references=labels)
    return {"BLEU": b, "TER": t}

# %%
class BERTScoreTrainer(Seq2SeqTrainer):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

    def compute_loss(self, model, inputs, return_outputs=False, score_type="f1"):
        # BERTScore
        labels = inputs.get("labels")
        outputs = model(**inputs)
        logits = outputs.get("logits")

        metric = load_metric("bertscore")
        metric.add_batch(predictions=logits, references=labels)
        scores = metric.compute(lang="en")
        if score_type == "p":
            loss = scores["precision"]
        elif score_type == "r":
            loss = scores["recall"]
        else:
            loss = scores["f1"]
        loss = -1 * torch.FloatTensor(loss).requires_grad_().mean().to(dev)
        return (loss, outputs) if return_outputs else loss

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    debug="underflow_overflow",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    report_to="all",
    # weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=1,
    fp16=True,
)
optimizer = Adafactor(
    model.parameters(),
    lr=1e-3,
    eps=(1e-30, 1e-3),
    clip_threshold=1.0,
    decay_rate=-0.8,
    beta1=None,
    weight_decay=0.0,
    relative_step=False,
    scale_parameter=False,
    warmup_init=False,
)

trainer_bs = BERTScoreTrainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["dev"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    optimizers=(optimizer, None),
)
# Out:
# PyTorch: setting up devices
# Using amp half precision backend

# %%
wandb.jupyter.__IFrame = wandb.jupyter.IFrame(
    opts={"height": 420, "workspace": False, "quiet": False}
)
trainer_bs.train()
wandb.finish()

wandb.jupyter.__IFrame = None
# Out:
# The following columns in the training set  don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: triple, sentence. If triple, sentence are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running training *****
#   Num examples = 104799
#   Num Epochs = 1
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 13100
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Could not locate the tokenizer configuration file, will try to use the model config instead.
# loading configuration file https://huggingface.co/roberta-large/resolve/main/config.json from cache at /home/ml/.cache/huggingface/transformers/dea67b44b38d504f2523f3ddb6acb601b23d67bee52c942da336fa1283100990.94cae8b3a8dbab1d59b9d4827f7ce79e73124efa6bb970412cd503383a95f373
# Model config RobertaConfig {
#   "_name_or_path": "roberta-large",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading file https://huggingface.co/roberta-large/resolve/main/vocab.json from cache at /home/ml/.cache/huggingface/transformers/7c1ba2435b05451bc3b4da073c8dec9630b22024a65f6c41053caccf2880eb8f.d67d6b367eb24ab43b08ad55e014cf254076934f71d832bbab9ad35644a375ab
# loading file https://huggingface.co/roberta-large/resolve/main/merges.txt from cache at /home/ml/.cache/huggingface/transformers/20b5a00a80e27ae9accbe25672aba42ad2d4d4cb2c4b9359b50ca8e34e107d6d.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# loading file https://huggingface.co/roberta-large/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/roberta-large/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/roberta-large/resolve/main/tokenizer_config.json from cache at None
# loading configuration file https://huggingface.co/roberta-large/resolve/main/config.json from cache at /home/ml/.cache/huggingface/transformers/dea67b44b38d504f2523f3ddb6acb601b23d67bee52c942da336fa1283100990.94cae8b3a8dbab1d59b9d4827f7ce79e73124efa6bb970412cd503383a95f373
# Model config RobertaConfig {
#   "_name_or_path": "roberta-large",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading configuration file https://huggingface.co/roberta-large/resolve/main/config.json from cache at /home/ml/.cache/huggingface/transformers/dea67b44b38d504f2523f3ddb6acb601b23d67bee52c942da336fa1283100990.94cae8b3a8dbab1d59b9d4827f7ce79e73124efa6bb970412cd503383a95f373
# Model config RobertaConfig {
#   "_name_or_path": "roberta-large",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file https://huggingface.co/roberta-large/resolve/main/pytorch_model.bin from cache at /home/ml/.cache/huggingface/transformers/8e36ec2f5052bec1e79e139b84c2c3089cb647694ba0f4f634fec7b8258f7c89.c43841d8c5cd23c435408295164cda9525270aa42cd0cc9200911570c0342352
# All the weights of RobertaModel were initialized from the model checkpoint at roberta-large.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaModel for predictions without further training.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_3673767/822881891.py in <cell line: 4>()
#       2     opts={"height": 420, "workspace": False, "quiet": False}
#       3 )
# ----> 4 trainer_bs.train()
#       5 wandb.finish()
#       6
#
# ~/.pyenv/versions/3.9.7/lib/python3.9/site-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1458                     elif self.do_grad_scaling:
#    1459                         scale_before = self.scaler.get_scale()
# -> 1460                         self.scaler.step(self.optimizer)
#    1461                         self.scaler.update()
#    1462                         scale_after = self.scaler.get_scale()
#
# ~/.pyenv/versions/3.9.7/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py in step(self, optimizer, *args, **kwargs)
#     334             self.unscale_(optimizer)
#     335
# --> 336         assert len(optimizer_state["found_inf_per_device"]) > 0, "No inf checks were recorded for this optimizer."
#     337
#     338         retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#
# AssertionError: No inf checks were recorded for this optimizer.
